# %% [markdown]
# '''Questions to answer
# 1) Is younger employees have more possibility of Attrition?
# 2) Is male employees have more possibility of Attrition?
# 3) What is the maximum distance from home?
# 4) Which department contain maximum employees?
# 5) Is higher salary employee has less chance of attrition as compared to lower salary employee?
# '''

# %%
#import liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
#reading the file
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# This is data of different employees having different columns out of which 9 are of object type (i.e. Attrition, Bussiness Travel etc.) and rest are of int64 type (i.e. Age, DailyRate etc.).

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# All the data is complete. There is no missing values.

# %% [markdown]
# # Is younger employees have more possibility of Attrition?

# %%
((pd.crosstab(df['Age'],df['Attrition'])['Yes']/(pd.crosstab(df['Age'],df['Attrition'])['Yes']+pd.crosstab(df['Age'],df['Attrition'])['No']))*100).plot.bar(figsize = (10,5))

# %% [markdown]
# Employee having age 19 and 20 have more than 50% attrition.

# %%
pd.crosstab(df['Age'],df['Attrition'])['Yes'].plot.bar(figsize=(10,5))

# %% [markdown]
# people having age 29 and 31 has more Attrition.

# %%
df['Age'].value_counts().plot.bar(figsize=(20,5)) #There are more people from 35 age

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# # Is male employees have more possibility of Attrition?

# %%
pd.crosstab(df['Gender'],df['Attrition'])
# Out:
# Attrition   No  Yes
# Gender
# Female     501   87
# Male       732  150

# %%
pd.crosstab(df['Gender'],df['Attrition'])['Yes']/(pd.crosstab(df['Gender'],df['Attrition'])['Yes']+pd.crosstab(df['Gender'],df['Attrition'])['No'])*100
# Out:
# Gender
# Female    14.795918
# Male      17.006803
# dtype: float64

# %% [markdown]
# Here we see Male has a little more percentage. So we cannot say male employees have more possibility of Attrition.

# %% [markdown]
# # What is the maximum distance from home?

# %%
max(df['DistanceFromHome'])
# Out:
# 29

# %%
(df[df['DistanceFromHome']==29]['Attrition']=='Yes').sum()
# Out:
# 5

# %%
df['DistanceFromHome'].hist()

# %% [markdown]
# # Which department contain maximum employees?

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# Research & Development department has most employees.

# %% [markdown]
# # Is salary effect Arrition?

# %%
max(df['MonthlyIncome'])
# Out:
# 19999

# %%
df['MonthlyIncome'].mean()
# Out:
# 6502.931292517007

# %%
x=(df[df['MonthlyIncome']<=6502.931292517007]['Attrition']=='Yes').sum()

# %%
y=(df[df['MonthlyIncome']<=6502.931292517007]['Attrition']=='No').sum()

# %%
x1=(x/(x+y))*100
x1
# Out:
# 18.93551688843398

# %%
x=(df[df['MonthlyIncome']>6502.931292517007]['Attrition']=='Yes').sum()

# %%
y=(df[df['MonthlyIncome']>6502.931292517007]['Attrition']=='No').sum()

# %%
x2=(x/(x+y))*100
x2
# Out:
# 10.547667342799189

# %% [markdown]
# Lower salary employees have 18.93% approax chances of Attrition
# Higher salary employees have 10.54% approax chances of Attrition
# So we can say that higher salary employee have low possibility of Attrition in comparision of lower salary employees.

# %%
pd.crosstab(df['MonthlyIncome'],df['Attrition']).plot.hist()

# %%
pd.crosstab(df['MonthlyIncome'],df['Attrition']).sum()
# Out:
# Attrition
# No     1233
# Yes     237
# dtype: int64

# %%
df['EducationField'].value_counts() #more employee from Life Science
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
x=(df['EducationField']=='Life Sciences').sum()
y=(df['EducationField']=='Medical').sum()
z=(df['EducationField']=='Marketing').sum()
r=(df['EducationField']=='Technical Degree').sum()
s=(df['EducationField']=='Other').sum()
t=(df['EducationField']=='Human Resources').sum()
x,y,z,r,s,t
# Out:
# (606, 464, 159, 132, 82, 27)

# %%
df1 = pd.DataFrame({'EducationField':[x,y,z,r,s,t]},index = ['Life Sciences','Medical','Marketing','Technical Degree','Other','Human Resources'])
plot = df1.plot.pie(y='EducationField',figsize=(10,10))

# %%
#More no. of employees are from LifeSciences and Medical.

# %%
max(df['TotalWorkingYears']) #I think it is an outliers
# Out:
# 40

# %%
df['TotalWorkingYears'].plot.box() #Yes it contain Outliers

# %%
df['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
df['Over18'].value_counts() #all are over 18. So we didnot need this columns.
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df.drop('Over18',axis = 1, inplace = True)

# %%
df['BusinessTravel'].value_counts()  #more employees travel rarely.
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# ...

# %% [markdown]
# EmployeeCount,StandardHours has only one value. So we do not need these columns more.

# %%
df.drop(['EmployeeCount','StandardHours'],axis = 1, inplace = True)

# %%
Columns = df.columns
# Out:
# pandas.core.indexes.base.Index

# %%
df.boxplot(figsize=(50,5))

# %% [markdown]
# There are outlier present in data

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %% [markdown]
# We didnot need EmployeeNumber because it will no effect attrition.

# %%
df.drop('EmployeeNumber', axis =1,inplace=True)

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.heatmap(df.corr(),annot=True,ax =ax)

# %% [markdown]
# Age and TotalWorkingYears have correlation of 0.68.
# Age and jobLevel have correlation of 0.51
# MonthlyIncome and joblevel have correlation of 0.95
# TotalWorkinghours and joblevel have correlation of 0.78
# Yearatcompany and jobleve have correlation of 0.53
# Age and Monthlyincome have correlation of 0.5
# TotalWorkinghours and Monthlyincome have correlation of 0.77
# PerformanceRating and PercentSalaryhike have correlation of 0.77
# Worklifebalane and TotalWorkinghours have correlation of 0.63
# Yearatcompany and Monthlyincome have correlation of 0.51
# Yearatcompany and TotalWorkinghours have correlation of 0.63
# Yearatcompany and Yearatcurrentrole have correlation of 0.76
# Yearatcompany and Yearsincelastpromotion have correlation of 0.62
# Yearatcompany and YearWithCurrManager have correlation of 0.77
# YearatCurrentRole and Yearsincelastpromotion have correlation of 0.55
# YearatCurrentRole and Yearwithcurrmanager have correlation of 0.71
# Yearsincelastpromotion and YearsWithCurrManager have correlation of 0.51

# %% [markdown]
# End
